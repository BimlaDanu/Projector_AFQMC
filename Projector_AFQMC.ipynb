# %% [markdown]
# ### Projector AFQMC Algorithms
#
#
#  - A second-order symmetric Trotter-Suzuki decomposition is used in our Monte-Carlo sampling approach for  imaginary time propagators
#
#     - $e^{-\Delta_\tau \hat{H}_\text{AFQMC}} = e^{-\frac{\Delta_\tau}{2} \hat{H}_t} e^{-\Delta_\tau \hat{H}_\text{int}}   e^{-\frac{\Delta_\tau}{2} \hat{H}_t}  + \mathcal{O}(\Delta_\tau^3)$.  Here,  $\Delta_\tau = \beta/L_\tau$ with  $L_\tau$ the number of Trotter slices and $\beta=\frac{1}{ k_B T}$ is inverse temperature
#
#  - In projector algorithm to generate the trial wave function $| \psi_0 \rangle = \lim\limits_{\Theta\rightarrow \infty}  e^{-\Theta {\hat H} } \big| \psi_T \big\rangle$.  Here, $2\Theta = L_\tau \Delta_\tau$ is the projection parameter with Trotter step $\Delta_\tau$
#
#
#  - Observables in the projective algorithm  are evaluated as,
#  $ \big\langle  {\hat O} \big\rangle  =\lim\limits_{\Theta \rightarrow \infty} \frac{\big\langle \psi_T \big| e^{-\Theta {\hat H}}  {\hat O}  e^{-\Theta {\hat H}}\big |\psi_T \big\rangle}{\big\langle \psi_T \big|e^{-2\Theta {\hat H}}\big|\psi_T \big\rangle}$
